# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Finger Classification Data
#
# On April 13th 2020 finger data classified for each of the 5 fingers was gathered on the right hand.
# Roughly 100 samples were gathered for each finger.
# The process of gathering the data was filmed. These recordings can be found [here.](/home/peter/Documents/Dissertation/Media/PickingFingers)
#
# Two datasets were gathered, one where my wrist was resting on a book and one where my hand was in the air.
# The book data was recoded first, then after a ~10 minute break the arm data was recorded.
#
# The source code used to gather this data and the data itself can be found in [this](https://github.com/PerlinWarp/myo-raw/commit/53fafc1bae404f045704e76cf6f7ea0e9aaaac2a) commit.

# %%
path = "../../data/FingerClassification/"
air_path = path+"fingers100air/"
book_path = path+"fingers100book/"

# %%
rest  = np.fromfile(air_path+"vals0.dat", dtype=np.uint16).reshape((-1, 8))
thumb  = np.fromfile(air_path+"vals1.dat", dtype=np.uint16).reshape((-1, 8))
index  = np.fromfile(air_path+"vals2.dat", dtype=np.uint16).reshape((-1, 8))
middle = np.fromfile(air_path+"vals3.dat", dtype=np.uint16).reshape((-1, 8))
ring   = np.fromfile(air_path+"vals4.dat", dtype=np.uint16).reshape((-1, 8))
pinky  = np.fromfile(air_path+"vals5.dat", dtype=np.uint16).reshape((-1, 8))
air_data = [rest, thumb, index, middle, ring, pinky]

# %%
air_df = pd.DataFrame(np.vstack(air_data))

# %% [markdown]
# ## Adding a labels column

# %%
a = rest
b = np.hstack((a, np.zeros((a.shape[0], 1), dtype=a.dtype)))

# %%
labelled_air_data = []
for i in range(len(air_data)):
    a = air_data[i]
    labels_col = np.ones((a.shape[0], 1), dtype=a.dtype)*i
    b = np.hstack((a, labels_col))
    labelled_air_data.append(b)

# %%
cols = ["Ch1","Ch2","Ch3","Ch4","Ch5", "Ch6", "Ch7", "Ch8", "Finger"]
air_df = pd.DataFrame(np.vstack(labelled_air_data), columns=cols)

# %%
#air_df.to_csv('air_df.csv',index=False)

# %%
air_df.var()
# Out:
# Ch1        1812.264351
# Ch2         707.429683
# Ch3       11453.020137
# Ch4         829.373456
# Ch5          57.278082
# Ch6         210.103684
# Ch7       13743.145907
# Ch8        3888.838090
# Finger        2.961367
# dtype: float64

# %%
plt.rcParams["figure.figsize"] = (20,10)
sns.heatmap(air_df.corr(), annot=True).set(title="sEMG and Finger corrolations")
# Out:
# [Text(0.5, 1.0, 'sEMG and Finger corrolations')]

# %%
# Replacing numerical fingernames with str
finger_names = ["rest", "thumb", "index", "middle", "ring", "pinky"]
air_df['Finger'] = air_df['Finger'].apply(lambda x: finger_names[x])

# %%
air_df.boxplot(by='Finger')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71c39be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71e1f820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71dc0c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71decf40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71da32e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71d4e640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71d5b5e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a71d06940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1a70e14040>]],
#       dtype=object)

# %%
air_df[['Ch3', 'Finger']].boxplot(by='Finger')

# %%
air_df.groupby('Finger').mean()
# Out:
#                Ch1         Ch2         Ch3         Ch4        Ch5        Ch6  \
# Finger
# index    40.989474  105.800000  254.884211  113.968421  52.073684  57.968421
# middle   49.413043   95.630435  435.108696  135.978261  56.445652  71.119565
# pinky   112.783505  111.278351  404.969072  140.319588  47.855670  55.907216
# rest     36.134021  109.979381  215.443299   99.402062  48.103093  47.144330
# ring     72.989011   83.879121  248.879121  106.318681  51.934066  68.406593
# thumb    38.680412   96.742268  228.701031  103.247423  49.453608  47.917526
#
#                Ch7         Ch8
# Finger
# index    54.884211   32.305263
# middle   57.630435   29.739130
# pinky    45.546392   40.030928
# rest     31.938144   22.907216
# ring    327.978022  177.263736
# thumb    33.793814   25.113402

# %%
import matplotlib

matplotlib.rc('figure', figsize=(15, 8))

air_df.plot(figsize=(15, 8))

# %%
sns.pairplot(air_df)

# %% [markdown]
# ## PCA

# %%
from sklearn import decomposition

X = air_df.drop(['Finger'],1).values
X.shape
# Out:
# (569, 8)

# %%
pca = decomposition.PCA()
pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [0.55974913 0.36318209 0.04492065 0.01305308 0.01260285 0.0034891
#  0.00193323 0.00106986]

# %%
X.shape
# Out:
# (569, 8)

# %%
pca = decomposition.PCA(n_components=2)
pca.fit(X)
Xp = pca.transform(X)

print(pca.explained_variance_ratio_)
# Out:
# [0.55974913 0.36318209]

# %%
finger_names
# Out:
# ['rest', 'thumb', 'index', 'middle', 'ring', 'pinky']

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(Xp[:,0], Xp[:,1])

# %%
plt.cm.nipy_spectral(5)
# Out:
# (0.18301960784313726, 0.0, 0.20913725490196078, 1.0)

# %%
principalDf = pd.DataFrame(data = Xp
             , columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([principalDf, air_df[['Finger']]], axis = 1)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = finger_names
colors = ['red', 'green', 'blue', 'pink', 'yellow', 'purple']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Finger'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(1, figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

y = air_df.Finger

ax.scatter(X[:, 0], X[:, 1], X[:, 2], cmap=plt.cm.nipy_spectral,
           edgecolor='k')

# %% [markdown]
# ## LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

X = air_df.drop(['Finger'], 1)
y = air_df.Finger

clf = LinearDiscriminantAnalysis()
clf.fit(Xp, y)

Xl = clf.transform(Xp)

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(Xl[:,0], Xl[:,1])

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

X = air_df.drop(['Finger'],1).values
Y = air_df.Finger

# split data into train and test sets
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# make predictions for test data
y_pred = model.predict(X_test)

y_pred
#predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 84.04%

# %%
from xgboost import plot_importance

# plot
plot_importance(model)

# %%
finger_names
# Out:
# ['rest', 'thumb', 'index', 'middle', 'ring', 'pinky']

# %%
fig, ax = plt.subplots()

colors = {'rest':'pink', 'thumb':'red', 'index':'green', 'middle':'blue', 'ring':'yellow', 'pinky':'purple'}
ax.scatter(air_df.index, air_df['Ch3'], c=air_df['Finger'].map(colors))

ax.set_title("Finger Movement by Channel 3")
ax.set_ylabel("Channel 3")
plt.show()

# %%
fig, ax = plt.subplots()

colors = {'rest':'pink', 'thumb':'red', 'index':'green', 'middle':'blue', 'ring':'yellow', 'pinky':'purple'}
ax.scatter(air_df.index, air_df['Ch7'], c=air_df['Finger'].map(colors))

ax.set_title("Finger Movement by Channel 7")
ax.set_ylabel("Channel 7")
plt.show()

# %%
ch = 5
channel = "Ch" + str(ch)
fig, ax = plt.subplots()

colors = {'rest':'pink', 'thumb':'red', 'index':'green', 'middle':'blue', 'ring':'yellow', 'pinky':'purple'}
ax.scatter(air_df.index, air_df[channel], c=air_df['Finger'].map(colors))
ax.legend()
ax.set_title("Finger Movement by " + channel)
ax.set_ylabel(channel)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(data, columns=np.unique(y_test), index = np.unique(y_test))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size
