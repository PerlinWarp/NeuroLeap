# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Blue Myo had 1498 readings
# Raw Myo has 1497 readings
#
#
# While collecting this data I had the red (Myo Raw) sensor on top, and the Blue (Blue Myo) sensor on the bottom.
# I moved my wrist from right to left and back again just like in Neuro-Breakout.

# %%
df = pd.read_csv("../data/dual_emg.csv")

# %%
df.head()
# Out:
#    Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  Channel_6  \
# 0         38         51         40         63        108        196
# 1         37         50         39         60         97        199
# 2         34         50         44         57         88        163
# 3         35         54         52         68         99        156
# 4         38         59         55         71         98        139
#
#    Channel_7  Channel_8  Channel_9  Channel_10  Channel_11  Channel_12  \
# 0         47         80       36.0        77.0        36.0       102.0
# 1         45         76       39.0        82.0        40.0       113.0
# 2         39         44       40.0        94.0        42.0       126.0
# 3         34         38       39.0       101.0        45.0       130.0
# 4         32         32       38.0       110.0        49.0       138.0
#
#    Channel_13  Channel_14  Channel_15  Channel_16
# 0        44.0       194.0        79.0        66.0
# 1        49.0       195.0        77.0        76.0
# 2        54.0       187.0        76.0        84.0
# 3        55.0       160.0        75.0        85.0
# 4        65.0       152.0        73.0        89.0

# %%
df.tail()
# Out:
#       Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  Channel_6  \
# 1493        125        274        388        160        120         65
# 1494        121        237        362        148        118         65
# 1495        110        264        340        138        121         64
# 1496         91        265        324        115        105         62
# 1497         85        282        279        102        100         59
#
#       Channel_7  Channel_8  Channel_9  Channel_10  Channel_11  Channel_12  \
# 1493         55         88      181.0       247.0       748.0       354.0
# 1494         54         84      164.0       225.0       770.0       329.0
# 1495         53         80      117.0       197.0       679.0       299.0
# 1496         50         74      105.0       198.0       690.0       287.0
# 1497         48         70        NaN         NaN         NaN         NaN
#
#       Channel_13  Channel_14  Channel_15  Channel_16
# 1493       231.0       180.0        95.0        77.0
# 1494       205.0       196.0        89.0        65.0
# 1495       195.0       184.0        86.0        59.0
# 1496       164.0       170.0        96.0        64.0
# 1497         NaN         NaN         NaN         NaN

# %%
# Drop the last row, as only Blue Myo got data for it. 
df = df.drop(1497)
# Out:
#       Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  Channel_6  \
# 0            38         51         40         63        108        196
# 1            37         50         39         60         97        199
# 2            34         50         44         57         88        163
# 3            35         54         52         68         99        156
# 4            38         59         55         71         98        139
# ...         ...        ...        ...        ...        ...        ...
# 1492        139        337        425        192        150         74
# 1493        125        274        388        160        120         65
# 1494        121        237        362        148        118         65
# 1495        110        264        340        138        121         64
# 1496         91        265        324        115        105         62
#
#       Channel_7  Channel_8  Channel_9  Channel_10  Channel_11  Channel_12  \
# 0            47         80       36.0        77.0        36.0       102.0
# 1            45         76       39.0        82.0        40.0       113.0
# 2            39         44       40.0        94.0        42.0       126.0
# 3            34         38       39.0       101.0        45.0       130.0
# 4            32         32       38.0       110.0        49.0       138.0
# ...         ...        ...        ...         ...         ...         ...
# 1492         65        106      209.0       251.0       765.0       388.0
# 1493         55         88      181.0       247.0       748.0       354.0
# 1494         54         84      164.0       225.0       770.0       329.0
# 1495         53         80      117.0       197.0       679.0       299.0
# 1496         50         74      105.0       198.0       690.0       287.0
#
#       Channel_13  Channel_14  Channel_15  Channel_16
# 0           44.0       194.0        79.0        66.0
# 1           49.0       195.0        77.0        76.0
# 2           54.0       187.0        76.0        84.0
# 3           55.0       160.0        75.0        85.0
# 4           65.0       152.0        73.0        89.0
# ...          ...         ...         ...         ...
# 1492       228.0       185.0        91.0        75.0
# 1493       231.0       180.0        95.0        77.0
# 1494       205.0       196.0        89.0        65.0
# 1495       195.0       184.0        86.0        59.0
# 1496       164.0       170.0        96.0        64.0
#
# [1497 rows x 16 columns]

# %%
import matplotlib

matplotlib.rc('figure', figsize=(15, 8))

df.plot()

# %%
sns.heatmap(df.corr(), annot=True).set(title="Multiple Myo Corrolations")
# Out:
# [Text(0.5, 1.0, 'Multiple Myo Corrolations')]

# %%
channels = ['Channel_1', 'Channel_9']

df[channels].plot()

# %%
channels = ['Channel_1', 'Channel_9', 'Channel_16']

df[channels].plot()

# %%
df.var()
# Out:
# Channel_1      1233.945773
# Channel_2     12624.588101
# Channel_3     20912.888424
# Channel_4      1514.137521
# Channel_5      3212.414773
# Channel_6     16540.682554
# Channel_7      2986.393408
# Channel_8      7213.580259
# Channel_9      5418.943932
# Channel_10    12773.526361
# Channel_11    86681.142176
# Channel_12    13701.924284
# Channel_13     3513.529643
# Channel_14    12129.727731
# Channel_15     9396.895383
# Channel_16     4388.661029
# dtype: float64

# %%
df['Channel_11'].plot()

# %%
df[['Channel_11', 'Channel_2']].plot()
